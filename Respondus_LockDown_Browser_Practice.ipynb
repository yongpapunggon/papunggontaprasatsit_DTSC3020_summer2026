# %% [markdown]
# <a href="https://colab.research.google.com/github/yongpapunggon/papunggontaprasatsit_DTSC3020_summer2026/blob/main/Respondus_LockDown_Browser_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Respondus LockDown Browser Practice Notebook
#
# This notebook is only for testing whether you can:
#
# 1. Open a Google Colab notebook during the Practice Quiz.
# 2. Save a copy to your Google Drive.
# 3. Rename the notebook as instructed.
# 4. Edit and run notebook cells.
# 5. Save the completed notebook to your GitHub repository.
# 6. Download the completed `.ipynb` file to your computer.
# 7. After submitting the Practice Quiz and exiting Respondus LockDown Browser, upload the downloaded file to the **Final Exam Practice Notebook Submission** assignment in Canvas.
#
# You do not need to copy or submit a GitHub link.
#
# **This activity is not a coding assessment.**

# %% [markdown]
# ## Step 1 — Save a copy to Google Drive
#
# In Google Colab, select:
#
# **File → Save a copy in Drive**
#
# Rename the copied notebook using this format:
#
# `FirstName_LastName_Practice.ipynb`

# %% [markdown]
# ## Step 2 — Enter your information
#
# Replace the example text below with your own information, and then run the cell.

# %%
# Replace the example information with your own information
student_name = "Papunggon Taprasatsit"


print("Student Name:", student_name)
# Out:
# Student Name: Papunggon Taprasatsit

# %% [markdown]
# ## Step 3 — Download the notebook
#
# In Google Colab, select:
#
# **File → Download → Download .ipynb**
#
# The download may not be visible while you are using Respondus LockDown Browser, but the file should still be saved to your computer.
#
# ## Step 4 — Save the notebook to GitHub
#
# In Google Colab, select:
#
# **File → Save a copy in GitHub**
#
# Then:
#
# 1. Select your GitHub repository.
# 2. Keep the notebook filename in the required format.
# 3. Add a commit message such as `Complete Respondus practice notebook`.
# 4. Click **OK**.
#
# You only need to save the notebook to GitHub. **You do not need to copy or submit the GitHub link.**
